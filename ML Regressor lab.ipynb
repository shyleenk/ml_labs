# %% [markdown]
# ## Notebook imports and packages

# %%
import pandas
from pandas import DataFrame
import matplotlib.pyplot as plt
from numpy import random
from numpy.random import binomial,poisson,normal
import numpy as np
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
X = OfficeSize =random.normal(100,10,100)   
y = OfficePrice = random.normal(10000,100,100)

# %%
regression = LinearRegression()

# %%
X = X.reshape(100,1)
y = y.reshape(100,1)
regression.fit(X,y)
print(regression.score(X,y))
gradient = regression.coef_
inter = regression.intercept_
# Out:
# 0.00017799959233721907

# %%
# Plot
X = X.reshape(100,1)
y = y.reshape(100,1)

regression.fit(X,y)

print(regression.score(X,y))

gradient = regression.coef_

inter = regression.intercept_

x_1 = np.linspace(80,120, 100)

x_2 = x_1.reshape(100,1)
plt.figure(figsize=[10, 10])

plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
line = inter + gradient * x_2
plt.plot(x_2, line, linewidth = 6, alpha = 0.8)
plt.grid()
plt.scatter(X, y, color='grey', s=300, alpha=0.6)
plt.title('Office Price vs Office Size')
plt.xlabel('Office Size')
plt.ylabel('Office Price')

plt.plot(100, gradient*100 + inter, 'r*',markersize= 20,  linewidth = 10, alpha = 0.8)
plt.show()
# Out:
# 0.00017799959233721907
